# %% [markdown]
# <a href="https://colab.research.google.com/github/sikandarmir/Open_CV_Cource/blob/main/Basic_Image_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import Image
import matplotlib as plt
# %matplotlib inline
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
#cv2_imshow(img)

# %%
img=cv2.imread("/content/drive/MyDrive/Data/images/IMG_20200605_174517_15.jpg",1)

# %%
#print(img)

# %% [markdown]
# #Accessing Individual Pixels

# %%
print(img[0,0,0])
print(img[1,1])
# Out:
# 2
# [0 0 1]

# %% [markdown]
# #Modifying Image Pixels
# We can modify the intensity values of pixel in the same manners as describe above

# %%
CP_IMG=img[:,:,::-1].copy()
import matplotlib.pyplot as plt

# %%
# CP_IMG[0:3000,0:200,0]=200
# CP_IMG[1,2,0]=200
# CP_IMG[2,2,2]=200
# CP_IMG[3,3,1]=200
# plt.imshow(CP_IMG)
# print(CP_IMG)

# %% [markdown]
# #Cropping Images

# %%
Crp_img=img[:,:,::-1]
Crp_region=Crp_img[550:,1000:2000]

plt.imshow(Crp_region)

# %% [markdown]
# #Resizing Images

# %%
width=250
height=250
re_image=img[:,:,::-1]
#Resize image into 250,250

# %%
resized_img=cv2.resize(re_image,(width,height),interpolation=cv2.INTER_AREA)

# %%
# plt.imshow(resized_img)

# %% [markdown]
# #Flipping Images
# flip_img=cv2.flip(src,flipcode)
# src=input_image
# flipcode= a flag to specfiy how to flip the array
#
# 0: mean x-axis
#
# 1: maen y-axis
#
# -1 mean to both axis

# %%
# img_flip_x_axis=cv2.flip(resized_img,0)
# img_flip_y_axis=cv2.flip(resized_img,1)
# img_flip_both_axis=cv2.flip(resized_img,-1)
# # Show images
# plt.figure(figsize=[25,5])
# plt.subplot(141);plt.imshow(img_flip_x_axis);plt.title("X_axis")
# plt.subplot(142);plt.imshow(img_flip_y_axis);plt.title("Y_axis")  
# plt.subplot(143);plt.imshow(img_flip_both_axis);plt.title("Both_axis")
# plt.subplot(144);plt.imshow(resized_img);plt.title("Orignal")

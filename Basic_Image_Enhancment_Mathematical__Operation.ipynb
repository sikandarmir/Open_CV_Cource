# %% [markdown]
# <a href="https://colab.research.google.com/github/sikandarmir/Open_CV_Cource/blob/main/Basic_Image_Enhancment_Mathematical__Operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import Image
import matplotlib as plt
# %matplotlib inline
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
#cv2_imshow(img)

# %%
img=cv2.imread("/content/drive/MyDrive/Data/images/IMG_20200605_174517_15.jpg",1)

# %% [markdown]
# #Basic_Image_Enhancment_Mathematical _Operation

# %%
img_rgb =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# #Addition Or Brightness

# %%
# matrix=np.ones(img_rgb.shape,dtype="uint8")*100
# img_rgb_brighter=cv2.add(img_rgb,matrix)
# img_rgb_darker=cv2.subtract(img_rgb,matrix)

# #Show Images
# plt.figure(figsize=[18,5])
# plt.subplot(131);plt.imshow(img_rgb_brighter);plt.title("Bright")
# plt.subplot(132);plt.imshow(img_rgb_darker);plt.title("Dark")
# plt.subplot(133);plt.imshow(img_rgb);plt.title("Orignal")

# %% [markdown]
# #Multiplication or Contrast

# %%
# matrix1=np.ones(img_rgb.shape)*0.8
# matrix2=np.ones(img_rgb.shape)*20

# img_rgb_brighter=np.uint8(cv2.multiply(np.float64(img_rgb),matrix1))
# img_rgb_dark=np.uint8(cv2.multiply(np.float64(img_rgb),matrix2))


# #Show Images
# plt.figure(figsize=[18,5])
# plt.subplot(131);plt.imshow(img_rgb_brighter);plt.title("Bright")
# plt.subplot(132);plt.imshow(img_rgb_darker);plt.title("Dark")
# plt.subplot(133);plt.imshow(img_rgb);plt.title("Orignal")

# %% [markdown]
# #Image Thresholding
# Binary Images have a lot of use in image processing.One of the most comman use casses is that of creating masks.Image Masks allow us to process on specfic parts of an image keeping the other parts intact.Image Thersholding is used to create Binary Images from grays scale in image.You can use different Thersholds to create different binary images from the same original image.
# #Function syntex
# retval,dst=cv2.thershold(src,thresh,maxvel,type[,dst])

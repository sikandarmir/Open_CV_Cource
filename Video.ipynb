# %% [markdown]
# <a href="https://colab.research.google.com/github/sikandarmir/Open_CV_Cource/blob/main/Video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

import time

# %%
sorce='/content/drive/MyDrive/Data/video.mp4'
cap=cv2.VideoCapture(sorce)

# %%
if(cap.isOpened()==False):
  print("Error Opening Video")

# %%
ret,frame=cap.read(1)
frame.shape
# Out:
# (352, 640, 3)

# %%
plt.imshow(frame[:,:,::-1])

# %% [markdown]
# #Read Video

# %%
# while(cap.isOpened()):
#   print('Hello')
#   ret,frame=cap.read()
#   if ret==True:
#     out_mp4.write(frame)
#   else:
#     break

# %%
cap.release()
out_mp4.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-4614bb4fe60b> in <module>()
#       1 cap.release()
# ----> 2 out_mp4.release()
#
# NameError: name 'out_mp4' is not defined
